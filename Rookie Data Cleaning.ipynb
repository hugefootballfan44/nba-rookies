# %% [markdown]
# # From Rookies to the All-NBA team
# # Step 1: Data Acquisition and Cleaning

# %% [markdown]
# ## Importing Libraries, Packages and Modules

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %% [markdown]
# ## Loading and Cleaning All-Rookie Data
#
# In order to attain a dataset conducive to modeling which NBA rookies will reach an All-NBA team, first we must load several datasets. These will then be merged together appropriately.
#
# The first dataset is 'End of Season Teams.csv', which contains data about which players made end-of-season teams such as All-NBA, All-Defense, All-Rookie, etc.
#
# All data for this project was taken from the NBA Stats (1947-Present) dataset posted on Kaggle by Sumitro Datta. This ata was scraped from Basketball-Reference.com.
#
# A link to the dataset can be found here: https://www.kaggle.com/datasets/sumitrodatta/nba-aba-baa-stats
#
# A link to Basketball Reference can be found here: https://www.basketball-reference.com/

# %%
df = pd.read_csv('End of Season Teams.csv', na_values = '?')

# %% [markdown]
# We want to have a variable indicating whether players made an All-Rookie team or not. For this, we start by filtering the type of team to 'All-Rookie' and drop columns that are irrelevant to the analysis (namely position and birth year).

# %%
df = df[df['type'] == 'All-Rookie'].drop(['position', 'birth_year'], axis = 1)

# %%
df
# Out:
#       season   lg        type number_tm              player  seas_id  \
# 25      2024  NBA  All-Rookie       1st       Chet Holmgren    31230
# 26      2024  NBA  All-Rookie       1st    Jaime Jaquez Jr.    31426
# 27      2024  NBA  All-Rookie       1st      Brandon Miller    31200
# 28      2024  NBA  All-Rookie       1st  Brandin Podziemski    31196
# 29      2024  NBA  All-Rookie       1st   Victor Wembanyama    31850
# ...      ...  ...         ...       ...                 ...      ...
# 2024    1963  NBA  All-Rookie       1st         Chet Walker     2476
# 2025    1963  NBA  All-Rookie       1st    Dave DeBusschere     2486
# 2026    1963  NBA  All-Rookie       1st       John Havlicek     2526
# 2027    1963  NBA  All-Rookie       1st    Terry Dischinger     2563
# 2028    1963  NBA  All-Rookie       1st         Zelmo Beaty     2584
#
#       player_id   tm  age
# 25         5125  OKC   21
# 26         5151  MIA   22
# 27         5121  CHO   21
# 28         5120  GSW   20
# 29         5209  SAS   20
# ...         ...  ...  ...
# 2024        762  SYR   22
# 2025        767  DET   22
# 2026        778  BOS   22
# 2027        788  CHZ   22
# 2028        791  STL   23
#
# [544 rows x 9 columns]

# %% [markdown]
# ## Loading Per-Game Data
#
# The next set of important variables for our model are player per-game statistics. We get this data by loading the 'Player Per Game.csv' dataset.

# %%
df2 = pd.read_csv('Player Per Game.csv', na_values = '?')

# %% [markdown]
# ## Merging and Cleaning Data
#
# Now we merge this new per-game data with the all-rookie data. We want to ensure that all rookies are included here, so we perform a left-join with the per-game data on the left.

# %%
df2 = df2.merge(df, how = "left", on = "seas_id", suffixes=('', '_y'))
df2.drop(df2.filter(regex = '_y$').columns.tolist(), axis = 1, inplace = True)

# %% [markdown]
# Now, we must filter this dataset to only include the rows and columns relevant to our model. We start by dropping the unnecessary 'birth_year' column.

# %%
df2 = df2.drop(['birth_year'], axis = 1)

# %% [markdown]
# Next, we filter the data to only include rookies (a.k.a. players with an experience value of 1 season).

# %%
df2 = df2[df2['experience'] == 1]

# %% [markdown]
# Subsequently, we only include players who had rookie seasons from 1988-89 onward. This is to ensure consistency in the dataset while still giving us enough observations to work with.
#
# The reason for choosing 1988-89 is because this is the season the NBA expanded the end-of-season teams to include a 3rd All-NBA team and a 2nd All-Rookie team. Moreover, many statistics (e.g. three-point field goals, steals, and blocks) were not tracked until varying points prior to 1988. This is a reasonable cutoff season as a result.

# %%
df2 = df2[df2['season'] > 1988]

# %% [markdown]
# Additionally, we will want to drop the 'type' column, as it is 'All-Rookie' or missing for all players. Moreover, to be more specifically pertaining to All-Rookie teams, 'number_tm' will be renamed.

# %%
df2 = df2.drop(['type'], axis = 1)

# %%
df2.number_tm = df2.number_tm.fillna('Not Selected')

# %%
df2.rename(columns={'number_tm': 'rookie_tm'}, inplace = True)

# %%
df2
# Out:
#        seas_id  season  player_id           player pos   age  experience   lg  \
# 7        31143    2024       5109     Adam Flagler  SG  24.0           1  NBA
# 8        31144    2024       5110     Adama Sanogo  PF  21.0           1  NBA
# 18       31154    2024       5111       Alex Fudge  SF  20.0           1  NBA
# 19       31155    2024       5111       Alex Fudge  SF  20.0           1  NBA
# 20       31156    2024       5111       Alex Fudge  SF  20.0           1  NBA
# ...        ...     ...        ...              ...  ..   ...         ...  ...
# 20491    11784    1989       2474   Vernon Maxwell  SG  23.0           1  NBA
# 20493    11786    1989       2475  Vinny Del Negro  SG  22.0           1  NBA
# 20502    11795    1989       2476  Wayne Engelstad  PF  23.0           1  NBA
# 20503    11796    1989       2477      Will Perdue   C  23.0           1  NBA
# 20504    11797    1989       2478  Willie Anderson  SF  22.0           1  NBA
#
#         tm   g  ...  orb_per_game  drb_per_game  trb_per_game  ast_per_game  \
# 7      OKC   2  ...           0.0           0.0           0.0           2.0
# 8      CHI   9  ...           2.1           1.9           4.0           0.0
# 18     TOT   6  ...           0.7           0.2           0.8           0.0
# 19     LAL   4  ...           0.5           0.0           0.5           0.0
# 20     DAL   2  ...           1.0           0.5           1.5           0.0
# ...    ...  ..  ...           ...           ...           ...           ...
# 20491  SAS  79  ...           0.6           1.9           2.6           3.8
# 20493  SAC  80  ...           0.6           1.5           2.1           2.6
# 20502  DEN  11  ...           0.5           1.0           1.5           0.6
# 20503  CHI  30  ...           0.6           0.9           1.5           0.4
# 20504  SAS  81  ...           1.9           3.3           5.1           4.6
#
#        stl_per_game  blk_per_game  tov_per_game  pf_per_game  pts_per_game  \
# 7               0.0           0.0           0.0          0.0           1.5
# 8               0.1           0.0           0.6          0.6           4.0
# 18              0.5           0.0           0.3          0.3           2.5
# 19              0.0           0.0           0.3          0.3           1.0
# 20              1.5           0.0           0.5          0.5           5.5
# ...             ...           ...           ...          ...           ...
# 20491           1.1           0.1           2.3          1.7          11.7
# 20493           0.8           0.2           1.0          2.0           7.1
# 20502           0.1           0.0           0.3          1.1           2.5
# 20503           0.1           0.2           0.5          1.3           2.2
# 20504           1.9           0.8           3.2          3.6          18.6
#
#           rookie_tm
# 7      Not Selected
# 8      Not Selected
# 18     Not Selected
# 19     Not Selected
# 20     Not Selected
# ...             ...
# 20491  Not Selected
# 20493  Not Selected
# 20502  Not Selected
# 20503  Not Selected
# 20504           1st
#
# [3170 rows x 35 columns]

# %% [markdown]
# In the data, we can see that Alex Fudge appears multiple times, as he played for multiple teams as a rookie. To account for players such as Fudge, we will remove all rows for these players except the ones containing their full-season stats. These rwos are the ones designated with 'TOT' as the team value.

# %%
multi_team = df2[df2['tm'] == 'TOT'].player_id

# %%
cond = df2['player_id'].isin(list(multi_team))

# %%
cond2 = df2['tm'] != 'TOT'

# %%
cond2
# Out:
# 7         True
# 8         True
# 18       False
# 19        True
# 20        True
#          ...
# 20491     True
# 20493     True
# 20502     True
# 20503     True
# 20504     True
# Name: tm, Length: 3170, dtype: bool

# %%
df2 = df2[~(cond & cond2)]

# %%
df2 = df2.reset_index()

# %%
df2 = df2.drop(['index'], axis = 1)

# %% [markdown]
# ## Loading All-Defense Data
#
# We would like to include more data to show which players made an All-Defense team as rookies. Such players are exceedingly rare, but this achievement would be a great indication of future NBA success.
#
# We attain this data by again using the 'End of Season Teams.csv' file.

# %%
df3 = pd.read_csv('End of Season Teams.csv', na_values = '?')

# %%
all_defense = df3[df3['type'] == 'All-Defense']
all_defense = all_defense.drop(['season', 'lg', 'type', 'player', 'player_id', 'position', 'tm', 'age', 'birth_year'], axis = 1)

# %% [markdown]
# ## Merging and Cleaning All-Defense Data
#
# Similarly as above, we will perform a left-join between the existing dataset on the left and the all-defense data on the right.

# %%
df2 = df2.merge(all_defense, how = "left", on = "seas_id", suffixes=('', '_y'))
df2.drop(df2.filter(regex = '_y$').columns.tolist(), axis = 1, inplace = True)

# %%
df2
# Out:
#       seas_id  season  player_id           player pos   age  experience   lg  \
# 0       31143    2024       5109     Adam Flagler  SG  24.0           1  NBA
# 1       31144    2024       5110     Adama Sanogo  PF  21.0           1  NBA
# 2       31154    2024       5111       Alex Fudge  SF  20.0           1  NBA
# 3       31160    2024       5112     Amari Bailey  PG  19.0           1  NBA
# 4       31161    2024       5113    Amen Thompson  SF  21.0           1  NBA
# ...       ...     ...        ...              ...  ..   ...         ...  ...
# 2803    11784    1989       2474   Vernon Maxwell  SG  23.0           1  NBA
# 2804    11786    1989       2475  Vinny Del Negro  SG  22.0           1  NBA
# 2805    11795    1989       2476  Wayne Engelstad  PF  23.0           1  NBA
# 2806    11796    1989       2477      Will Perdue   C  23.0           1  NBA
# 2807    11797    1989       2478  Willie Anderson  SF  22.0           1  NBA
#
#        tm   g  ...  drb_per_game  trb_per_game  ast_per_game  stl_per_game  \
# 0     OKC   2  ...           0.0           0.0           2.0           0.0
# 1     CHI   9  ...           1.9           4.0           0.0           0.1
# 2     TOT   6  ...           0.2           0.8           0.0           0.5
# 3     CHO  10  ...           0.3           0.9           0.7           0.3
# 4     HOU  62  ...           4.2           6.6           2.6           1.3
# ...   ...  ..  ...           ...           ...           ...           ...
# 2803  SAS  79  ...           1.9           2.6           3.8           1.1
# 2804  SAC  80  ...           1.5           2.1           2.6           0.8
# 2805  DEN  11  ...           1.0           1.5           0.6           0.1
# 2806  CHI  30  ...           0.9           1.5           0.4           0.1
# 2807  SAS  81  ...           3.3           5.1           4.6           1.9
#
#       blk_per_game  tov_per_game  pf_per_game  pts_per_game     rookie_tm  \
# 0              0.0           0.0          0.0           1.5  Not Selected
# 1              0.0           0.6          0.6           4.0  Not Selected
# 2              0.0           0.3          0.3           2.5  Not Selected
# 3              0.0           0.4          0.2           2.3  Not Selected
# 4              0.6           1.5          2.3           9.5           2nd
# ...            ...           ...          ...           ...           ...
# 2803           0.1           2.3          1.7          11.7  Not Selected
# 2804           0.2           1.0          2.0           7.1  Not Selected
# 2805           0.0           0.3          1.1           2.5  Not Selected
# 2806           0.2           0.5          1.3           2.2  Not Selected
# 2807           0.8           3.2          3.6          18.6           1st
#
#       number_tm
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 2803        NaN
# 2804        NaN
# 2805        NaN
# 2806        NaN
# 2807        NaN
#
# [2808 rows x 36 columns]

# %% [markdown]
# We also again rename the 'number_tm' column appropriately.

# %%
df2.rename(columns = {'number_tm': 'defense_tm'}, inplace = True)

# %%
df2[df2['defense_tm'] == '1st']
# Out:
#      seas_id  season  player_id             player pos   age  experience   lg  \
# 100    31850    2024       5209  Victor Wembanyama   C  20.0           1  NBA
#
#       tm   g  ...  drb_per_game  trb_per_game  ast_per_game  stl_per_game  \
# 100  SAS  71  ...           8.4          10.6           3.9           1.2
#
#      blk_per_game  tov_per_game  pf_per_game  pts_per_game  rookie_tm  \
# 100           3.6           3.7          2.2          21.4        1st
#
#      defense_tm
# 100         1st
#
# [1 rows x 36 columns]

# %% [markdown]
# ## Loading All-NBA Data
#
# We would also like to include more data to show which players made an All-NBA team as rookies. Such players are again exceedingly rare, but this achievement would also be a great indication of future NBA success.
#
# We attain this data by once again using the 'End of Season Teams.csv' file.

# %%
all_nba = df3[df3['type'] == 'All-NBA']

# %%
all_nba = all_nba.drop(['season', 'lg', 'type', 'player', 'player_id', 'position', 'tm', 'age', 'birth_year'], axis = 1)

# %% [markdown]
# ## Merging and Cleaning All-Defense Data
#
# Similarly as above, we will perform a left-join between the existing dataset on the left and the all-NBA data on the right.

# %%
df2 = df2.merge(all_nba, how = "left", on = "seas_id", suffixes=('', '_y'))
df2.drop(df2.filter(regex = '_y$').columns.tolist(), axis = 1, inplace = True)

# %% [markdown]
# We also again rename the 'number_tm' column appropriately.

# %%
df2.rename(columns = {'number_tm': 'nba_tm'}, inplace=True)

# %% [markdown]
# Moreover, we fill in the missing values with 'Not Selected'.

# %%
df2.defense_tm = df2.defense_tm.fillna('Not Selected')

# %%
df2.nba_tm = df2.nba_tm.fillna('Not Selected')

# %%
df2
# Out:
#       seas_id  season  player_id           player pos   age  experience   lg  \
# 0       31143    2024       5109     Adam Flagler  SG  24.0           1  NBA
# 1       31144    2024       5110     Adama Sanogo  PF  21.0           1  NBA
# 2       31154    2024       5111       Alex Fudge  SF  20.0           1  NBA
# 3       31160    2024       5112     Amari Bailey  PG  19.0           1  NBA
# 4       31161    2024       5113    Amen Thompson  SF  21.0           1  NBA
# ...       ...     ...        ...              ...  ..   ...         ...  ...
# 2803    11784    1989       2474   Vernon Maxwell  SG  23.0           1  NBA
# 2804    11786    1989       2475  Vinny Del Negro  SG  22.0           1  NBA
# 2805    11795    1989       2476  Wayne Engelstad  PF  23.0           1  NBA
# 2806    11796    1989       2477      Will Perdue   C  23.0           1  NBA
# 2807    11797    1989       2478  Willie Anderson  SF  22.0           1  NBA
#
#        tm   g  ...  trb_per_game  ast_per_game  stl_per_game  blk_per_game  \
# 0     OKC   2  ...           0.0           2.0           0.0           0.0
# 1     CHI   9  ...           4.0           0.0           0.1           0.0
# 2     TOT   6  ...           0.8           0.0           0.5           0.0
# 3     CHO  10  ...           0.9           0.7           0.3           0.0
# 4     HOU  62  ...           6.6           2.6           1.3           0.6
# ...   ...  ..  ...           ...           ...           ...           ...
# 2803  SAS  79  ...           2.6           3.8           1.1           0.1
# 2804  SAC  80  ...           2.1           2.6           0.8           0.2
# 2805  DEN  11  ...           1.5           0.6           0.1           0.0
# 2806  CHI  30  ...           1.5           0.4           0.1           0.2
# 2807  SAS  81  ...           5.1           4.6           1.9           0.8
#
#       tov_per_game  pf_per_game  pts_per_game     rookie_tm    defense_tm  \
# 0              0.0          0.0           1.5  Not Selected  Not Selected
# 1              0.6          0.6           4.0  Not Selected  Not Selected
# 2              0.3          0.3           2.5  Not Selected  Not Selected
# 3              0.4          0.2           2.3  Not Selected  Not Selected
# 4              1.5          2.3           9.5           2nd  Not Selected
# ...            ...          ...           ...           ...           ...
# 2803           2.3          1.7          11.7  Not Selected  Not Selected
# 2804           1.0          2.0           7.1  Not Selected  Not Selected
# 2805           0.3          1.1           2.5  Not Selected  Not Selected
# 2806           0.5          1.3           2.2  Not Selected  Not Selected
# 2807           3.2          3.6          18.6           1st  Not Selected
#
#             nba_tm
# 0     Not Selected
# 1     Not Selected
# 2     Not Selected
# 3     Not Selected
# 4     Not Selected
# ...            ...
# 2803  Not Selected
# 2804  Not Selected
# 2805  Not Selected
# 2806  Not Selected
# 2807  Not Selected
#
# [2808 rows x 37 columns]

# %% [markdown]
# ## Loading Advanced Data
#
# The next set of important variables for our model are player advanced statistics. We get this data by loading the 'Advanced.csv' dataset.

# %%
advanced = pd.read_csv('Advanced.csv', na_values = '?')

# %%
advanced = advanced.drop(['season', 'player_id', 'player', 'birth_year', 'pos', 'age', 'experience', 'lg', 'tm', 'g'], axis = 1)

# %% [markdown]
# ## Merging and Cleaning Advanced Data
#
# Similarly as above, we will perform a left-join between the existing dataset on the left and the advanced data on the right.

# %%
df2 = df2.merge(advanced, how = "left", on = "seas_id", suffixes=('', '_y'))
df2.drop(df2.filter(regex = '_y$').columns.tolist(), axis = 1, inplace = True)

# %%
df2
# Out:
#       seas_id  season  player_id           player pos   age  experience   lg  \
# 0       31143    2024       5109     Adam Flagler  SG  24.0           1  NBA
# 1       31144    2024       5110     Adama Sanogo  PF  21.0           1  NBA
# 2       31154    2024       5111       Alex Fudge  SF  20.0           1  NBA
# 3       31160    2024       5112     Amari Bailey  PG  19.0           1  NBA
# 4       31161    2024       5113    Amen Thompson  SF  21.0           1  NBA
# ...       ...     ...        ...              ...  ..   ...         ...  ...
# 2803    11784    1989       2474   Vernon Maxwell  SG  23.0           1  NBA
# 2804    11786    1989       2475  Vinny Del Negro  SG  22.0           1  NBA
# 2805    11795    1989       2476  Wayne Engelstad  PF  23.0           1  NBA
# 2806    11796    1989       2477      Will Perdue   C  23.0           1  NBA
# 2807    11797    1989       2478  Willie Anderson  SF  22.0           1  NBA
#
#        tm   g  ...  tov_percent  usg_percent  ows  dws   ws  ws_48  obpm  \
# 0     OKC   2  ...          0.0         21.7  0.0  0.0  0.0 -0.159  -6.7
# 1     CHI   9  ...         13.4         24.8  0.1  0.1  0.2  0.133  -0.4
# 2     TOT   6  ...         11.2         19.2  0.0  0.0  0.0 -0.007  -3.7
# 3     CHO  10  ...         12.9         21.1 -0.1  0.0 -0.1 -0.044  -5.2
# 4     HOU  62  ...         14.9         18.5  1.9  2.4  4.3  0.149  -0.1
# ...   ...  ..  ...          ...          ...  ...  ...  ...    ...   ...
# 2803  SAS  79  ...         16.0         20.9  0.1  1.4  1.5  0.035  -1.3
# 2804  SAC  80  ...         12.3         16.4  1.5  1.0  2.5  0.077  -1.7
# 2805  DEN  11  ...          8.2         27.9  0.0  0.1  0.0  0.031  -5.0
# 2806  CHI  30  ...         16.1         21.0 -0.3  0.2 -0.1 -0.021  -6.7
# 2807  SAS  81  ...         15.6         23.8  2.1  2.8  4.9  0.085   0.8
#
#       dbpm   bpm  vorp
# 0     -3.9 -10.6   0.0
# 1     -6.3  -6.7  -0.1
# 2     -1.5  -5.2   0.0
# 3     -3.1  -8.3  -0.1
# 4      1.9   1.8   1.3
# ...    ...   ...   ...
# 2803  -1.2  -2.5  -0.3
# 2804   0.5  -1.2   0.3
# 2805  -1.7  -6.7  -0.1
# 2806  -1.6  -8.3  -0.3
# 2807   0.4   1.3   2.3
#
# [2808 rows x 58 columns]

# %% [markdown]
# # Adding Actual All-NBA Outcomes
#
# We also need to include the actual career outcomes for players in the dataset. We start this process by acquiring the player_id for every player who made an All-NBA team.

# %%
all_nba_ids = df3[df3['type'] == 'All-NBA']['player_id']

# %% [markdown]
# Now we create a dataframe with these player ids and 'all_nba' values of True. We also make sure to drop the duplicate rows representing players who were selected to multiple All-NBA teams.

# %%
outcomes = pd.DataFrame({'player_id': all_nba_ids, 'all_nba': True})

# %%
outcomes = outcomes.reset_index()

# %%
outcomes = outcomes.drop(['index'], axis = 1)

# %%
outcomes = outcomes.drop_duplicates()

# %% [markdown]
# Next, we perform a left-join between the previous features data on the left and the new labels data on the right. We also fill in the resulting missing values in the 'all_nba' column with False.

# %%
df2 = df2.merge(outcomes, how = "left", on = "player_id", suffixes=('', '_y'))
df2.drop(df2.filter(regex = '_y$').columns.tolist(), axis = 1, inplace = True)

# %%
df2.all_nba = df2.all_nba.fillna(False)

# %%
#profile = ProfileReport(df2,title="Data Profile")

# Save the report to .html
#profile.to_file("data_profile.html")

# %%
df2[df2['all_nba'] == True]
# Out:
#       seas_id  season  player_id             player pos   age  experience  \
# 314     28972    2021       4808    Anthony Edwards  SG  19.0           1
# 398     29613    2021       4892  Tyrese Haliburton  PG  20.0           1
# 441     28537    2020       4723          Ja Morant  PG  20.0           1
# 570     27864    2019       4630      Jalen Brunson  PG  22.0           1
# 594     28015    2019       4654        Luka Dončić  SG  19.0           1
# ...       ...     ...        ...                ...  ..   ...         ...
# 2680    11937    1990       2509          Glen Rice  SF  22.0           1
# 2714    12190    1990       2544         Shawn Kemp  PF  20.0           1
# 2722    12219    1990       2552       Tim Hardaway  PG  23.0           1
# 2778    11657    1989       2449     Mitch Richmond  SG  23.0           1
# 2790    11714    1989       2461     Rod Strickland  PG  22.0           1
#
#        lg   tm   g  ...  usg_percent  ows  dws   ws  ws_48  obpm  dbpm  bpm  \
# 314   NBA  MIN  72  ...         27.0 -0.6  1.4  0.8  0.017  -0.4  -1.7 -2.1
# 398   NBA  SAC  58  ...         18.1  2.8  0.7  3.5  0.096   1.9  -0.5  1.4
# 441   NBA  MEM  67  ...         25.9  2.3  1.5  3.8  0.088   1.4  -1.2  0.3
# 570   NBA  DAL  73  ...         19.1  1.5  1.0  2.6  0.077  -1.2  -0.5 -1.7
# 594   NBA  DAL  72  ...         30.5  2.1  2.8  4.9  0.101   3.6   0.3  3.9
# ...   ...  ...  ..  ...          ...  ...  ...  ...    ...   ...   ...  ...
# 2680  NBA  MIA  77  ...         21.6 -0.4  1.8  1.4  0.029  -2.1  -1.1 -3.2
# 2714  NBA  SEA  81  ...         22.4  0.5  1.6  2.1  0.092  -2.2   0.2 -2.0
# 2722  NBA  GSW  79  ...         20.5  1.9  1.4  3.3  0.060   0.6  -0.8 -0.2
# 2778  NBA  GSW  79  ...         26.2  3.6  1.9  5.6  0.098   1.3  -1.4 -0.1
# 2790  NBA  NYK  81  ...         23.3  2.2  1.5  3.7  0.131   1.7   0.4  2.2
#
#       vorp  all_nba
# 314   -0.1     True
# 398    1.5     True
# 441    1.2     True
# 570    0.1     True
# 594    3.4     True
# ...    ...      ...
# 2680  -0.7     True
# 2714   0.0     True
# 2722   1.2     True
# 2778   1.3     True
# 2790   1.4     True
#
# [119 rows x 59 columns]

# %% [markdown]
# # Finishing Touches
#
# There are 18 columns for rate statistics, including 'fg_percent', 'ft_percent', 'x3p_percent', 'ws_48', and more, that contain missing values for players who saw little playing time. These missing values will all be replaced with zeroes.

# %%
df2 = df2.fillna(0)

# %%
df2.to_csv('rookie.csv')
